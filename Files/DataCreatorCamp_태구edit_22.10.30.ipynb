# %% [markdown]
# # ImageDataGenerator
# datagen = ImageDataGenerator(
#         rotation_range=40,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
#         fill_mode=`nearest`)'
#
# rotation_range: 이미지 회전 범위 (degrees)<br>
#
# width_shift, height_shift: 그림을 수평 또는 수직으로 랜덤하게 평행 이동시키는 범위 (원본 가로, 세로 길이에 대한 비율 값)<br>
#
# rescale: 원본 영상은 0-255의 RGB 계수로 구성되는데, 이 같은 입력값은 모델을 효과적으로 학습시키기에 너무 높습니다 (통상적인 learning rate를 사용할 경우). 그래서 이를 1/255로 스케일링하여 0-1 범위로 변환시켜줍니다. 이는 다른 전처리 과정에 앞서 가장 먼저 적용됩니다.<br>
#
# shear_range: 임의 전단 변환 (shearing transformation) 범위<br>
#
# zoom_range: 임의 확대/축소 범위<br>
#
# horizontal_flip: True로 설정할 경우, 50% 확률로 이미지를 수평으로 뒤집습니다. 원본 이미지에 수평 비대칭성이 없을 때 효과적입니다. 즉, 뒤집어도 자연스러울 때 사용하면 좋습니다.<br>
#
# fill_mode 이미지를 회전, 이동하거나 축소할 때 생기는 공간을 채우는 방식

# %%
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
drive.mount('/content/drive')
# 모델 학습에 용이한 데이터 불러오기
train_data_dir = '/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet'

np.random.seed(15)

#제너레이터로 이미지 사이즈가 고정되도록 함
train_datagen = ImageDataGenerator(rescale = 1. /255)
#opencv로 진행해볼것
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size =(300, 300),
    batch_size = 100, # 25503개로 수정해봐야함
    class_mode = 'categorical',
)

x,y = train_generator.next()

img_dataFrame = pd.DataFrame({'이미지 픽셀값':list(x), '타깃값':list(y)})
img_dataFrame.head(100)


#print('X_train shape: ', x[0].shape)
#print(x[0])
#plt.imshow(x[0])
#plt.show()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f1c85d68b2c> in <module>
#       5 train_data_dir = '/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet'
#       6
# ----> 7 np.random.seed(15)
#       8
#       9 #제너레이터로 이미지 사이즈가 고정되도록 함
#
# NameError: name 'np' is not defined

# %% [markdown]
# # 새로운 방법

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files
import pandas as pd
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')
#시각화 처리
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# Out:
# Mounted at /content/drive

# %%
img_dataFrame = pd.DataFrame(columns=['image address'], index = range(25503))
img_dataFrame.shape
# Out:
# (25503, 1)

# %%
import os
 
img_path_list = []
possible_img_extension = ['.jpg', '.jpeg', '.JPG', '.bmp', '.png'] # 이미지 확장자들

np.random.seed(15)

directory_path = '/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet'
directory_list = os.listdir(directory_path)
print(directory_list)


dl=[]

label = []
count = -1
for i in  directory_list:
  dl.append('/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/'+i)


for dlf in dl:
  count +=1
  label_count = 0
  for (root, dirs, files) in os.walk(dlf):
    if len(files) > 0:
      for file_name in files:
        label.append(count)
        label_count+=1

        if os.path.splitext(file_name)[1] in possible_img_extension:
          img_path = root + '/' + file_name
                
          # 경로에서 \를 모두 /로 바꿔줘야함
          img_path = img_path.replace('\\', '/') # \는 \\로 나타내야함         
          img_path_list.append(img_path)
    print(label_count)
    label_count+=1
                             
#print(img_path_list)
img_dataFrame['image address'] = img_path_list
img_dataFrame['label'] = label
img_dataFrame.shape
img_dataFrame.head(10000)
# Out:
# ['L2_10', 'L2_12', 'L2_15', 'L2_20', 'L2_21', 'L2_24', 'L2_25', 'L2_27', 'L2_3', 'L2_30', 'L2_33', 'L2_34', 'L2_39', 'L2_40', 'L2_41', 'L2_44', 'L2_45', 'L2_46', 'L2_50', 'L2_52']
# 1893
# 518
# 1509
# 410
# 410
# 782
# 6189
# 426
# 595
# 364
# 6206
# 419
# 454
# 180
# 593
# 547
# 631
# 2214
# 781
# 382
#                                           image address  label
# 0     /content/drive/MyDrive/Colab Notebooks/DataCre...      0
# 1     /content/drive/MyDrive/Colab Notebooks/DataCre...      0
# 2     /content/drive/MyDrive/Colab Notebooks/DataCre...      0
# 3     /content/drive/MyDrive/Colab Notebooks/DataCre...      0
# 4     /content/drive/MyDrive/Colab Notebooks/DataCre...      0
# ...                                                 ...    ...
# 9995  /content/drive/MyDrive/Colab Notebooks/DataCre...      6
# 9996  /content/drive/MyDrive/Colab Notebooks/DataCre...      6
# 9997  /content/drive/MyDrive/Colab Notebooks/DataCre...      6
# 9998  /content/drive/MyDrive/Colab Notebooks/DataCre...      6
# 9999  /content/drive/MyDrive/Colab Notebooks/DataCre...      6
#
# [10000 rows x 2 columns]

# %%
from PIL import Image

img_list_np = []

for i in img_path_list:
    image = Image.open(i)
    if image.mode != 'RGB': 
      image = image.convert('RGB') #RGB 모드가 아닌 이미지를 rgb로 변환
    image = image.resize((100,100)) #이미지 사이즈 설정

    img_array = np.array(image)
    img_list_np.append(img_array)
    print(i, " 추가 완료 - 구조:", img_array.shape) # 불러온 이미지의 차원 확인 (세로X가로X색)
    #print(img_array.T.shape) #축변경 (색X가로X세로)
# Out:
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cvleystsurkczhmvnrmt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ycrqupsfbtdmppsedlxl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xvrshedtlvgyjdfyjmls.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/enraiajslpvuvcpdwhce.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iggmyrvxuuodahwxdpcs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wweggkosnfiqvyseukfa.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/btuixnvjxcztpmutlehv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pwehgcayutliqfvyvxcm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ywvcpgvdseczxblykqby.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bmctcsqlzotwfhmvrnjo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yvbwzrlpguqttezhtlxd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ffocqetmmvkteycgsmck.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kqtknvbpeuozxsfonyle.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hprfyqqtnjchtjthdcpi.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/paxpbdkbvoqxhdxwedpw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lsithrllssmnjefptmap.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/taakajvwzmqpvtqgyavg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mknujapdyzaiblxganym.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yrdncdzyvtuhucnegluy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mqqxrlwghsnfxwgpbmch.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gasvarinlwxwjsyyqgav.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/airwdxvrtemeyyhotzol.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/sadmbpefqvuuptmajovh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ezzuzgabbzxxmiizskcr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/punfqsvigcyjewwdgwhk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/irxuxxjqjnusphkbfoqd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nhgufhpzmoxxdirmwzxh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zojaubxowhgexyxsnscu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ayhvjsjlovsjdudaeswa.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ootgufrwqvgmbjjndpan.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/krpmyvvkdeolfqwbdguf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/srhmncjdzmgroutgwzzu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/smitznpasnvrhgbsyprk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gswzsmvieveitqfclrrd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uberhjseldwzpkvdlxln.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lldkgabzmfwkhkpayirm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zczzfapfkuggvpeuvugw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bormvnlvnvlmkcpvesom.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/agncxlfheqbbavhlqdxo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pzacfqgwsaltpwafwssn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/shrrteysqgdwjctxrnzg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/etazgcghkvtslyfzagac.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cckwnpefgqlmfzguxqnk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cdkewmhnindykalrlzjq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wwooqesfztjnhrbeaxwb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/enjzlnfzrcmvxzjmlacq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jlgecdfbkcvgpqvuhivz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fvnvlhbtrfnmxcofnyht.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/npeafqogajlfrbxvmiua.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zmhqwvketosazxjtbbtp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mymiocbzcqkhpvsactbt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ltyyfqcfovfvikghevfb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rcypkjmiuaexnykeyehl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dknbcoqiuvenyqrwaqfp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cfralqgwkkbamersiakg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ysgddrtdvlqpvxolpqud.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dpccuzivruggzekbkhoo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zfxzkchjelacznzbzdav.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vidrljumoovxhhntrhsb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mmwmklpjwcopavabocib.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fboeivfkpldguesdfjrv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/saifxocjlofnlstcaxqu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wjifoyyriwpfboitcphg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xhwjahylfpunegmpktzn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dpshoemdvxoelbsoeqqk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uhemkxpivggeupbvpnbc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/svenlsvmovtjqffypsvl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/menqefisxrncigjgracb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ntjxiqaeknfpwsxftrsh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wctwcugnaktjrruhzcsj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wamronhranrgihhdlhce.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nyhguvssrrvzuhukbceo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uzimxbkpbamwdhpyotni.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vsijljloqtzutkqeonrh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iodnyjedjdvfdgxnxxyb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/llapzhhcqwwqsnnqpacu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/adifywyfmtduwlbotdky.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qjyouwqyavywlxaggxrh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mgardfqsehsyijiprnbl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cpkjqqhvswuufevpvqzt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iajbucvsxtdpumjakvoj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mzthajhngkpdypwvsnem.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/whsuosdcxrfwlxwskowm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wguvqqdcfuzlgocgizhk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lxcmqzchspgpjlhbahme.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rknwnxhsquucbfekgxrf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rpdtqdfwlfymfgrkdjwp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wflojeyhauzrvaoriius.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ogkbvfjdtdjlwqcaicpt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cawwrcfippkzpxyluofk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/llijoegypcjqagayjjvc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/puxidvrablmwcgulhhho.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vkmtssxtxjmluxmwrqdy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lrskubyiimhesvesncuf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zjzhwsgzcffvpoczefhq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rsmyllmzjiedtaqhxtxv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uzchdqmgnitsiwvfzsga.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vwbwstdynnqbphbblgtl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rbkquimyhaypxfhvchqd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zeaolzxyyjfzkyywcadq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uzndjzggwjeucajccoag.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gykosmmvhqfysjqjscdy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mqpksldevcusuozyhlhr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nrhmurtvsxcnsrwtzoas.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/oecclyugyfrmrvnsyvck.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nvaklebcsrmzzkhxvaft.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uthfswhyayonhhovvswh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ttprjzyzckkgtdulmslb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/aqbbnplaprdsftppbiij.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zfyybvyufxbhuugbynpq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/amcwcxodzpllfnrxryze.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vsrwinxvghtwdjeihjjv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pspxbaezximgxxcsdzyv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gmwaqzusvaoueermrnor.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/milymxaomrdlwxhnumkl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pihnknrcnrzofqguvlyy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qehfwqkfnarqsdpwuyab.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vlqkxyacgcuopxrzzhof.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/igewljfoqsmcormzpdht.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bwghymadjleqxnghvbsv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qqcjwuvajgmejnvnbjzo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yytshpdsaruttlgqjcpm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/odmuqnyyteiwklbtbrcl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/eouobixqgywfoelrnwrn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fwfmiqkxklnrtyozkydq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zfxhgfqkptcjzfrlgktv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ghpelnyedqxlcuyteqjq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rokrjkukutegsnztaisz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mtgvehvrzcxefrwmxkbd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/egshtsquzooylrsccnru.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wckzctqxsfrgfvwrgwpb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/awmaaqkpkhbkefegvzvu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hefvijodxdxotobjhebi.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cfamylpubmgnredytwgr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wvbzdledbbdzjctweung.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/thqgutcoamynudgprbfs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/szarybjdcdblzwssclbg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jbzgyebbhtkfslyxjabs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bvtpnzewuzizqmgnpkne.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ylkmkbceixbjeblpsuav.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nmawkxqpqzwnimofakcp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gfmdjrrhkfljlwaoztlv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rmlorbybqvidbcuabgeb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kfknxzfzedhntixhivge.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rfxwkimxblktcgollsce.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rqwpbtdtjdkwtywvkvas.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/oujfabrggbckdrzyucoe.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ebdmqxaqaobnimntlljk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pqnlltdsmhauradsbhbm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uxzbyqvsqhuzeejfuidf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xpdpzpsdsqnbjsombfjr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iyncooshrewjklwnfyvm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cplwapvxsddbnrfnepnn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/obcplxkwpsnuixyjtbtk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lvopghadfltwajwsfkvn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qwurxfnjkesllonjlmjw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ltfexabuhcznxnafhpgk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tsiupkeyhagsyfauahgs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/swcuelgrqyxwncrhpxte.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/auiajmqgaqschfulerep.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/brtuxzaeyefpfjaietoh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/llnpbexrhcbhlsxzeiaa.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dvqfnaebhcskpprhlais.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bifyeszigkfqygcqktgr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nupmuknhuufktlnbgrff.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dcofpliprhnqxdjqjmcd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ckwerggfmkncbrznrmkl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ddkjusrqoloxfnrxxyiv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qvuzznugeaadhpaphuvv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lulxjkpksbozvwrsbonf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ktjeictiyqrbzllkdkns.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/upiidmwyggcfxllnxmpv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mextudwkbrzobcaphgvz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bpexexgpqcztkfkejpbo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mzjgbnbhwrhhdkvwkkua.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/amfgbxhscfqvjmlgpkzh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gwakcnshysiyjtlefprh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lhjtjlwrkeisnxqvkqce.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lbikrbwkwviskfvathtb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qhkfblsynulardibgpkg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hgarbjtalgbggqojtnsk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zrsnsjhprfymbbgehqcf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zctzfztsdrpifanobjos.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ugacbpmujfwdksdaotmn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/sudcrjsyjeczurtnklgm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/svbpxjdzayxjloeygyqy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xqjcpixdyylvwitsduiw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/alhborguuvbvnuthbztt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uheaqtbejjwtftipvgoc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gxorhsejmthqvubvzxnk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mejwkdvmsseicbtdvara.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zzefpbqwtcihuotcufyt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hornpspekfcyoiiggcvz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/juuzkmtrhsasfeuehzwu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kcqkrzrgsiyzratkpmuf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jpzftufkpjhdujuemdqf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/owfkpvhzmnbhhilmzjqv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kqpbueqluqwqqynjibjr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hwnezjrhnonxrvyxczgb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rifeubptzkwgkelhpuxt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/emcjoiaobquvdknegbqc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jdzlfldfyntcsyoaegeo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/haadejwmxzmgpxbesxzp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lbejmdoxhsemnfoyhlgr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mkdpnmtxpnqgstnexlxj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/skmbyxmwukzahykwokky.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/thopvqzdybcljfrhthxv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/aegkmchbtjysohrncydf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rmzossmuvoajigjrfmbt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/neykkmsckhxhaukbrhqo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ppcurwotpzpkzzqytptl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iqfqrrcciwfrwkotnrku.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xxnicneiikarvdxqpflq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wwoebnazbxbcftkvizrf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/clwrodffgvyokattflpb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hgqquishopweknwckjku.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kkwpstggjmwhqewywgwz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ooketdutdbzzbcntvrsz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iymwtpuammivitesahoe.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gbakjubnoijnibvramtw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fdwkrvuljwamhaxcmoia.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bgrvrdgalzzmhkpbxqus.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mkxjvaxbkgdkjvfmsmrh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ipamrcnzjewhzycneypj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/iujqzlsielpgtppytrdc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gtvvapbhropssxjbeekk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rsndbyazfbpptovtaajq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kthzmxhyxzyuruhgybgx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/trdpqdgbnjlafnmkqzuh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cxsnfcicslbxktikdbwg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vreahmifjfpefszolajg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uoeqvaweekmgwtieepsd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cwdjbcenuxbuupmjkmkt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mthrjiqpmkmbeufoglte.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dryursvbkdwonicvzqvy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/atzdydjkatzuwvclvpwf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dijwioyavwpycnvfymay.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/aknjihylvztqcfrxdwcs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nvivqlpgmzgixkzgnhvv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yhwmvnsifhmrvmmyknba.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rrnhbjmlvewdqbgilbzp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/sxzdtjqardkjzzciwrvl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kqktamlbfnlaszinhhdc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wjmuilqvrimvpgmwpjax.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/moahqkathhfnylmgxrtc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pjvqxyivzaraitgcgwnp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lbylffikekhldjvxphis.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/conynftkcqdabcjvykof.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qgnsxiohftgogugdjbvw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uykkzmremrgltzvwyeab.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tcqtirswsmammigqnrak.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/oaafsezarzajbgjdsngf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mtjkkihephobcfkacwdc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/afalpcuekknfvfhiysjg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/amokhskvzwemfotwyaew.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wsrcohzghnkzkkzsoxgo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tfbszrbmfuxjfynphzwn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rmrnsqcdvxttjamfrtfn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vzjakcpqsbwtmlrjzdiw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/omzribievgqxzqzenwsv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/evektsqswxcthmdfekko.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tfwfpvlauhuoxjabjxpl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gnbphgrkynqdthmevpvu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vkdednbprxyagbfclans.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/eufhcvcqvfekxeqptenn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uuhujxepmhchobmhedgy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zelytmlwjoyxzxgkfnaw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nrqkypvdsqvrzqucnbwc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fvroeowqaeufibdwgtuo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tyulazbpmzaulnhtkupf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kmzxdsmmzuuqgpfeonbu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bnbkqgviwuptlyzzwhwm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hnwghljftfxiqcnetuuv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rzvtxckfdqbqvsobmsnl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nzuqyxvuvlcicwqdwtng.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/abymagsohyagiheolkhk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ixtsvazutptpgadtehgr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tpjrzieqegvppqiuwxhr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/chipmjtrcopbmndlfjep.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zitnpogddqrpqzpvqzaj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nbvzhwbjzgpebhqqavfs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/myhhcmmjwyvaijzruucj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dmtaousmflpvxkmqsghp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dedwitswzahvxvdeqlwd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nqcmhxwuubtgkkyydwbe.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zffyanzclygjvrzthcnx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/qraxhmqfidwfhfviosht.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ccxmshffguxolrnzprwy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/srvglonfnlixlweodwul.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fwnedycycjfwgsaevnet.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/goqjfchasjnteluorbmm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lztrpupkvbgvuyhacvda.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nxvyibbtsoddtjpuekay.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zibifyuexmyoxjeyfsfp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tolcbhxnsxetdcazcuut.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hsmqttbuzptzsmhdrsrk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/piydeivlgdqcpbmhytbf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tgicldbgqrxeyqommpht.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gkxhphhxgadmopbfmmst.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yisnvlormmtjjamwxksj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rcmgazphbaiszdweeyqd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/bxiweshhlafersyeqowq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/gthpchjbpjqlirinopuc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/azdyyodzycviyepaqodo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ucnkeewholbnsfsusiuw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uqubqcqwkdtidiphczok.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/swbbnnfpcxsvdtkafjmj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rswlhdqiixpubegwkhez.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/brpurzvbedcecziobkmk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zobiwnesnibvdsegokvf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xwvjdruarbpufzjkstos.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ukfjpchpaaoxylovzzgp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jkmmcriqwoohphquieyu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/okohmajjqpspthuijkll.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uprjpzislmpqiqcfvxby.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xgallsedwiciqrpwziiy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pajlmlkevyopoyyvhoso.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mtvgssiahruuatifebpn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dhfifbydzljxkljwlsxo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mkcppayxagpuvckhuchc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xmmndethfcspxitetjto.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/futkvcvudbxuhillrbzs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/noyercgtpsufkptkbqiy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/dfsaduklxhirplvahnui.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fzlkemrfdjrhnrucvlxv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rojjbjqulcxncefkebrm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uektimbkbimioneqgtlp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fxejmvcxouzpriyjbedi.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/eeofabhvyovvjkbcbybv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/slotnaxcfqchnlhaimti.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mfkitbeosedqyotiszdr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ythqqlgfqrdakboglblg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/germzpocqkipncrfewzm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vxrlxztwkgoiodtquyuk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/aveukrupyystarfcdgnr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/zfpecwvueorxsnctvnjh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nggsaiqvrolfxnuydncb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pokbvfzrcsrlzfjckvve.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tgiojjcapnwywibqbyxf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/oiogalamnluhhuagefgm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uphcivalaicshjlzatrs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/htbiqxeaiwiyechbeelu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wstrqmqqsiqrthbqmmqf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/imiscygkgxxlmtefwxfl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yxvvcnzzlwanenmbaunu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yxfidmdnukbnxvlczfcx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/okcccpwrlhfwtshprsbo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fdzydqullmtlsrtuwsvg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/kmxfqmybcclsxidtqlbp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jdoaktprwuygfytlmaar.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yntjpehiddyroxpzfxat.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fkxrsmkdagjjviowcavf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yiyxnreerlsrsgrmiiuh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/adzihlnlmguqfbmnlexu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/otbbokyxmoqjyaagghql.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/xvrqugkzegcqviaftghr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/pfcwdkgaaknjqsostuei.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rvrgyyphtxvovmttsqde.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/aoguwpvugxfzzsdtomzf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/duvcjmbgjaknwnnaefbx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hsowmsqowxrmsgcneybu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tunudalqdafjuqkpkwuk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fjkqcvmnjqnugolgwjui.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/sliyiuxpblesneljydju.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/egillhaifxpeqklvrqnx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wafltblmccegejxhkcbr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lwetbcxfuhmbywtxrfgp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/szpdijkljpszlevwonie.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rhbqnlypssuipkljarwt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/awjolzgfvnrppbmwlahw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/difxbqtunqihnthjxdfp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/frrdngofnybynlbuqogs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/asmiylrzypxapazhgeif.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ckgdjoyoxowgveagcczp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/cphemhaggianrlixjamu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/tfkalgkyxceparzdnsyn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/vepoibdqvyzooefiizoy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/rzffqrvrdwsbyhlunndf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ruqddbmskmuenfxtqlck.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fltutdxohcnnkkjflhbz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hhxetpxtxlfoxzqednng.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mrfgwarogiqxskzvbsfz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/jdsdkoowplmybwlsajww.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ciuledaagudcvaujaeuy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/ibuimzzsjwmfxarocdik.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/fiaqruilwfzobdghwhvc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/yuculgybfvbfddsbawig.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/beflpbqhfmzzjdqvloma.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/uhnhzdtdiblgubsnwrwd.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/nkuiadbzodgtuzezkizj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/wfeenpsidousjgwrlxga.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/frzwklrhugkajpsthlde.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/mwismteoxxzbqikbiniy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/lvyubdiftranoybsgrfa.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/imiqcvmnvzbqpjrdcsqj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_10/hoyxnyznysitkqyahzdd.jpg  추가 완료 - 구조: (100, 100, 3)
# ...
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/emtvbtdgotcigpjufghy.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/tuxofzepeoyiwdjihpyd.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/kfsqrppqzplxembxhyuo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/rpcjjwddhyzfoqlpywss.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/xlsvhrbrqiqohhhggqmk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/esgatidrjnngwxphssze.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vdaaguibkfykledcvjcy.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hkjmhbkkypmwzsprpgun.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ttemsvtygomrsvhkiyxm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/yjluhlueebavpyegvzpw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/fetkcdmcfzgksylvpjdw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/xetizxegntrgoqawbifu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/bxotygikgfgxgpbzovkk.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/smreueihbnxlzovsjxtk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/khwyeocbfymwlxevnksu.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/oizldjzbskwdyzizeohs.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/sioiqglbzlkybnmomiun.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/csllssulpdbcbyorahmj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/egsfrzvsmhyoysdnlxaj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/adnxcbdttmdxphaheqfv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/gzxmsfrgwcjpgeinerph.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ikevjkotznhcpzgckuav.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/jhsxuywmmrmtnmhocoth.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zinmshehkkzbdmnflpjj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/uhhyuysnpoyvanfzhthu.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/owqpupwqtaguvafzddrn.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/awzszvzjfrehyzlgmhpn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zukfkicrimhykqtrxkbe.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/trbtfhisftphctlampwg.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/oljbzgdnmzmucodtqbwu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hbtghydwnrqhiqfdxnjx.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/kwpilkknnfnjtdvlbinv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zkrynkyugtrpxppyddez.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/mtgwrqcuchhiunqvercw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hjwpdveewltzcdjarudy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/nbtbthbtrlxwiyrdaccz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ohfybdapztygwwaxzvqg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/raqqefxcsguyjuiaiffh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dimuxtaqprwvvhyegklw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hgbosjwjhnfgaqqkruwz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/trksvxrtzrrrbbmcznvz.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vhrhpjllelxolugcmfen.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/yiujztyrebcjiueuztzr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/feuuaggmwfxjuefgaxys.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vybakmsoixwdjjyericz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vegigygwpinoeqtlfssj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/nxnivnvkkxzjyeraohbl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/lnkbgysvgpadoqongcpz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dzqdibhoupmuoavtmmrw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/gnkdvlxoojfnwnfiomhp.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/spmvffgnicbewzpnhnov.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/aquimzjaeqqpenqacxrn.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/eimgpdyonksoemelgaex.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/pxrxaaymzknuuqoanzqm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ytcwrsejskiguncduaor.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/qjwsscgvhjdamitbqtup.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/iwdpogkatgwtchprkxtx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/kgqrdoajvhjweicvexyw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/pytlxnffodywysnccvia.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/awtibrwmbhixhubqofie.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/mcgphvgktfvoakjzqqfh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/eelfbkugilyyyvwuvhup.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/jeingsbtpxgzgwnajnad.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/nxpsxyefkpykyujgosmj.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vqrphnvuidsxhqxmygfu.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/jhiabdakomtrbjhtvucr.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/qcmhktkisekedpeldrdo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hairowthvcdrdtsnqwnm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zjpzapcppcmecbkkodku.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dhtjaaeqtvynhewuttpt.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/lzmfjakewezxufeajlzz.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/bllbzckswbzhxvuuvfbk.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/fqnyeuznumeqwtdwrnly.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/mmrzenilvhkfwiotcmwh.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/tkvixigfglyrkrvyctwg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/lmsmeozfexfnmpviqyqc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/eannrjluuqvakfqbqmkm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/izuohbjqmejuwtfqulcv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ifgdetomwsyotguuzrpg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/xlsctepjhpafwlraaqmg.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/samighofdqyqyhxmdini.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/svfmpchqvofkonazuqjt.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vlqgyhlrwzfjohohzuvw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ghhzpyntnaqbcbzgkyop.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/oafptndpiiuwjjfknoff.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/idruyptgnluwnrhgzrqt.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/iliupehyijqrvnzlgtau.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/pussjqwlorgpzmsklkuv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/exegyeevnuakxhkiwnau.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/jgokvkqzzvibtdctqpwj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/vesbsayjzpexbfrvprpz.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/rynuylzaqzifyrxplusm.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/anudstsrjnyzvjtlfghl.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/gkztstlwoonircftbrcm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/pmcezzenevedsswyfjwx.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/kyrsqbpgewsmubhwzszx.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ziilzbnnfosmidlpscjv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/xwwrotbclxxzvqlkmejn.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dxylgpyzpvcfahtzofbb.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/pblxuknsbxujymklosgh.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/fxiuydzxrimhnbnilbnv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/awdllxrsplbydyvsfqle.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/qtpfiycrtzhphdlbspok.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zixeqhshjsxerkdlkloy.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/oornmzhjwajblmnsplzw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/zwioxnzjuiufsjztftts.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/tceioqlqlpipxeotpvmd.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/mlxniodtoojvinulwlek.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/erafsncgnsrbxrokknfm.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/qlpndoywckziwlmpnypw.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/aloinlhummuqrgckwudj.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/bzzqczaujtpxdpmdxyvc.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/rjpwygfshusuytimmegf.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/hrigoskdpxjvldxcgsxr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/ynsvjfnheucjavjcbgwb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/wlgvgsdouhbejqizxfuo.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/unnvduzzdaapywkhdmig.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/gujugydgevnlqmtxlghr.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/cuxdnvdrxvztubltqmdx.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/txqamqkhueywutzebylw.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dfnzqeultwftajjmsnsj.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/mlwseaoakkolrypfvjxb.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/kgylmsktwdpvjipuxcjy.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/qczuebrrxkrhxexubqxe.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/nuvykcocsxhgpchadiik.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dpngxxqgngecscrgtrdl.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/xazvpjwaydqrbvpjbvul.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/fbkloojqdqzzvyzjhrfv.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/bzzgdseklzecfcoujbaf.png  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/cpexnivtruoevtlazloq.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/yifaakzphsggoouohtan.jpg  추가 완료 - 구조: (100, 100, 3)
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/DataSet/L2_52/dtxfpcggpnrgqolnmdoy.png  추가 완료 - 구조: (100, 100, 3)

# %%
#img_np : 이미지를 넘파이배열로 만든것
img_np = np.array(img_list_np) #리스트를 numpy로 변환
print(img_np.shape)

#img_dataFrame['image numpy'] = img_np

np.save('./sample_data', img_np)  # x_save.npy
np.save('/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/sample_data.npy', img_np)
print(img_np.shape)
print("저장 완료")
# Out:
# (25503, 100, 100, 3)
# (25503, 100, 100, 3)
# 저장 완료

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

sample_data = np.load('/content/drive/MyDrive/Colab Notebooks/DataCreatorCamp/sample_data.npy')
# fruits = np.load('fruits_300.npy')
# If M is (32 x 32 x 3), then .reshape(1,-1) will produce a 2d array (not 1d), of shape (1, 32*32*3).
# That can be reshaped back to (32,32,3) with the same sort of reshape statement.
sample_data_2d = sample_data.reshape(-1, 100 * 100 * 3)

print("sample_data의 shape 맞추기:", sample_data)
print("sample_data_2d의 shape 맞추기:", sample_data_2d)
# 여기에서 출력되는 차원의 숫자가 같아야 한다.
print("sample_data.shape:", sample_data.shape)
print("sample_data_2d.shape:", sample_data_2d.shape)
# Out:
# sample_data의 shape 맞추기: [[[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [ 90  90  90]
#    [127 127 127]
#    [ 94  94  94]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [ 98  98  98]
#    [ 68  68  68]
#    [ 28  28  28]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [135 135 135]
#    [119 119 119]
#    [ 54  54  54]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  ...
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]]
# sample_data_2d의 shape 맞추기: [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# sample_data.shape: (25503, 100, 100, 3)
# sample_data_2d.shape: (25503, 30000)

# %%
from sklearn.cluster import MiniBatchKMeans
import matplotlib.pyplot as plt
minibatch_kmeans = MiniBatchKMeans(n_clusters=10, batch_size=10,random_state=42)
minibatch_kmeans.fit(sample_data_2d)

fig = plt.figure(figsize=(15,7))
km_labels = minibatch_kmeans.labels_
km_centers = minibatch_kmeans.cluster_centers_
colors = plt.cm.Spectral(np.linspace(0,1,len(set(km_labels))))
ax = fig.add_subplot(1,1,1)
for k, col in zip(range(3),colors):
  my_members = (km_labels == k)
  cluster_center = km_centers[k]
  ax.plot(sample_data_2d[my_members, 0], sample_data_2d[my_members, 1],'w',markerfacecolor = col, marker = '.')
  ax.plot(cluster_center[0], cluster_center[1],'o',markerfacecolor = col, markeredgecolor = 'k',markersize=8)
ax.set_title('K-Means')
ax.set_xticks(())
ax.set_yticks(())
plt.show()

# %%
from sklearn.cluster import KMeans

# K값을 지정해 준다.random_state=항상 값은값이 랜덤하게 나온다.
km = KMeans(n_clusters=250, random_state=42)
# 사이킷 런의 철학은 nxd, 갯수x차원
km.fit(sample_data_2d)
# 할당된 레이블의 결과를 볼 수 있다.
print("km.labels_", km.labels_)
print("km.labels_.shape", km.labels_.shape)
print("첫번째:", km.labels_[0:])

print(np.unique(km.labels_, return_counts=True))
print(km.labels_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-2f451b274ce8> in <module>
#       4 km = KMeans(n_clusters=250, random_state=42)
#       5 # 사이킷 런의 철학은 nxd, 갯수x차원
# ----> 6 km.fit(sample_data_2d)
#       7 # 할당된 레이블의 결과를 볼 수 있다.
#       8 print("km.labels_", km.labels_)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1178             # Initialize centers
#    1179             centers_init = self._init_centroids(
# -> 1180                 X, x_squared_norms=x_squared_norms, init=init, random_state=random_state
#    1181             )
#    1182             if self.verbose:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _init_centroids(self, X, x_squared_norms, init, random_state, init_size)
#    1092                 n_clusters,
#    1093                 random_state=random_state,
# -> 1094                 x_squared_norms=x_squared_norms,
#    1095             )
#    1096         elif isinstance(init, str) and init == "random":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     217         # Compute distances to center candidates
#     218         distance_to_candidates = _euclidean_distances(
# --> 219             X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     220         )
#     221
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     369     else:
#     370         # if dtype is already float64, no need to chunk and upcast
# --> 371         distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     372         distances += XX
#     373         distances += YY
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (
#
# KeyboardInterrupt:

# %%
#elbow 기법으로 최적의 cluster 찾기
import matplotlib.pyplot as plt
sse= []
for i in range(1,11):
  km = KMeans(n_clusters=i,init='k-means++',random_state = 0)
  km.fit(sample_data_2d)
  sse.append(km.inertia_)
plt.plot(range(1,11),sse,marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47084 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 53364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47084 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 53552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 2, in where
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 2, in where
# KeyboardInterrupt

# %%
# Out:
# [[254.36460369 254.39771987 254.40608035 ... 253.70141151 253.66221498
#   253.59185668]
#  [111.22232824 109.4976145  105.46755725 ...  95.03435115  88.63311069
#    81.01669847]
#  [254.87469184 254.89835881 254.87581883 ... 254.66985983 254.62992181
#   254.63133056]]
# [0 2 0 ... 0 2 0]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
km = KMeans(n_clusters=25, random_state=42)
km.fit(sample_data_2d)
print(km.cluster_centers_)
print(km.labels_)
fig = plt.figure(figsize=(15,7))
km_labels = km.labels_
km_centers = km.cluster_centers_
colors = plt.cm.Spectral(np.linspace(0,1,len(set(km_labels))))
ax = fig.add_subplot(1,1,1)
for k, col in zip(range(3),colors):
  my_members = (km_labels == k)
  cluster_center = km_centers[k]
  ax.plot(sample_data_2d[my_members, 0], sample_data_2d[my_members, 1],'w',markerfacecolor = col, marker = '.')
  ax.plot(cluster_center[0], cluster_center[1],'o',markerfacecolor = col, markeredgecolor = 'k',markersize=8)
ax.set_title('K-Means')
ax.set_xticks(())
ax.set_yticks(())
plt.show()
# Out:
# [[254.01498127 254.03183521 253.95318352 ... 252.70224719 252.70411985
#   252.73220974]
#  [254.93721973 254.93721973 254.92096413 ... 254.93890135 254.93890135
#   254.92264574]
#  [177.12295082 185.30122951 190.9897541  ... 111.79918033 109.12090164
#   101.57581967]
#  ...
#  [254.82783229 254.84032114 254.85013381 ... 254.99732382 254.99732382
#   254.9955397 ]
#  [110.38336052 104.30995106  96.48450245 ...  73.25122349  64.78466558
#    56.55954323]
#  [255.         255.         254.99606041 ... 254.86342745 254.86999343
#   254.86802364]]
# [ 7  6 16 ...  9 24 24]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
km = KMeans(n_clusters=50, random_state=42)
km.fit(sample_data_2d)
print(km.cluster_centers_)
print(km.labels_)
fig = plt.figure(figsize=(15,7))
km_labels = km.labels_
km_centers = km.cluster_centers_
colors = plt.cm.Spectral(np.linspace(0,1,len(set(km_labels))))
ax = fig.add_subplot(1,1,1)
for k, col in zip(range(3),colors):
  my_members = (km_labels == k)
  cluster_center = km_centers[k]
  ax.plot(sample_data_2d[my_members, 0], sample_data_2d[my_members, 1],'w',markerfacecolor = col, marker = '.')
  ax.plot(cluster_center[0], cluster_center[1],'o',markerfacecolor = col, markeredgecolor = 'k',markersize=8)
ax.set_title('K-Means')
ax.set_xticks(())
ax.set_yticks(())
plt.show()
# Out:
# [[254.76855895 254.83624454 254.87991266 ... 254.82751092 254.82969432
#   254.83624454]
#  [177.57728707 186.60567823 194.08201893 ...  92.49526814  89.73817035
#    80.78864353]
#  [254.97843666 254.96091644 254.93261456 ... 255.         255.
#   254.99865229]
#  ...
#  [253.77494692 253.77919321 253.76220807 ... 254.22929936 254.22929936
#   254.22929936]
#  [254.76583211 254.75699558 254.75699558 ... 254.73637703 254.72312224
#   254.83799705]
#  [254.98924731 254.98924731 254.98387097 ... 255.         255.
#   254.99462366]]
# [33 24 26 ... 42 23 23]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
km = KMeans(n_clusters=100, random_state=42)
km.fit(sample_data_2d)
print(km.cluster_centers_)
print(km.labels_)
fig = plt.figure(figsize=(15,7))
km_labels = km.labels_
km_centers = km.cluster_centers_
colors = plt.cm.Spectral(np.linspace(0,1,len(set(km_labels))))
ax = fig.add_subplot(1,1,1)
for k, col in zip(range(3),colors):
  my_members = (km_labels == k)
  cluster_center = km_centers[k]
  ax.plot(sample_data_2d[my_members, 0], sample_data_2d[my_members, 1],'w',markerfacecolor = col, marker = '.')
  ax.plot(cluster_center[0], cluster_center[1],'o',markerfacecolor = col, markeredgecolor = 'k',markersize=8)
ax.set_title('K-Means')
ax.set_xticks(())
ax.set_yticks(())
plt.show()
# Out:
# [[254.98969072 255.         255.         ... 255.         255.
#   255.        ]
#  [255.         255.         255.         ... 254.35087719 254.36842105
#   254.42105263]
#  [255.         254.997151   255.         ... 255.         254.997151
#   255.        ]
#  ...
#  [254.66352201 254.66352201 254.6572327  ... 254.67295597 254.67295597
#   254.66666667]
#  [255.         255.         254.98561151 ... 255.         255.
#   255.        ]
#  [254.96837945 254.94268775 254.90118577 ... 255.         255.
#   254.99802372]]
# [41 13 77 ... 42 97 30]

# %%
import matplotlib.pyplot as plt


def draw_sample_data(arr, ratio=1):
    n = len(arr)  # n은 샘플 개수입니다
    # 한 줄에 10개씩 이미지를 그립니다. 샘플 개수를 10으로 나누어 전체 행 개수를 계산합니다.
    print(n)
    rows = int(np.ceil(n / 10))
    # 행이 1개 이면 열 개수는 샘플 개수입니다. 그렇지 않으면 10개입니다.
    cols = n if rows < 2 else 10
    fig, axs = plt.subplots(rows, cols,
                            figsize=(cols * ratio, rows * ratio), squeeze=False)
    for i in range(rows):
        print(i)
        for j in range(cols):
            if i * 10 + j < n:  # n 개까지만 그립니다.
                print(i)
                axs[i, j].imshow(arr[i * 10 + j], cmap='gray_r')
            axs[i, j].axis('off')
    plt.show()


draw_sample_data(sample_data[km.labels_ == 0])
draw_sample_data(sample_data[km.labels_ == 1])
draw_sample_data(sample_data[km.labels_ == 2])
draw_sample_data(sample_data[km.labels_ == 3])
draw_sample_data(sample_data[km.labels_ == 4])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # OPENCV 사용해보기
# import cv2
#
# **메서드 imread()**
# cv2.imread(filename, flag) : 이미지를 읽어 Numpy 객체로 만드는 함수
# flag
#
#
# *   IMREAD_COLOR : 이미지를 COLOR로 읽고 투명한 부분 무시
# *   IMREAD_GRAYSCALE : 이미지를 Grayscale로 읽기
# *   IMREAD_UNCHAGED : 이미지를 Color로 읽고, 투명한 부분도 읽기(Alpha)
#
# 반환 값 : Numpy 객체(행, 열, 생상 : 기본 rgb)
#
# **메서드 imshow(title, image)**
# cv.imshow(title, image) : 특정한 이미지 출력
#
# 코랩에서는 아래와 같이 사용가능
# from google.colab.patches import cv2_imshow
# cv2_imshow(img)
#
# **메서드 imwrite**
# cv.imwrite(file_name, image) : 이미지 저장하기
#
# **이미지의 행렬 표현**
# 한 픽셀 당 rgb로 표현<br>
#
# **메서드 cvtColor()**
# cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# + 처음 cv2로 이미지를 불러오면 픽셀의 정보가 BGR순
# + matplotlib같은 라이브러리는 RGB순으로 받아와야 하기에 BGR에서 RGB로 픽셀정보의 순서를 변경
#
#
# **메서드 resize()**
# cv2.resize(image, dsize, fx, fy, interpolation) : 이미지 크기 조절
#
# - dsize : Manual size(None)
# - fx : 가로 비율
# - fy : 세로 비율
# - interpolation : 보간법
#   + INTER_CUBIC : 사이즈를 크게할 때
#   + INTER_AREA : 사이즈를 작게 할 때
#
#
# **메서드 warpAffine()**
# cv2.warpAffine(image, M, dsize) : 위치 옮기기
# + M : 변환행렬
# + dsize : Manual Size
#
# **메서드 add()**
# cv2.add(image1, image2) : Saturation 연산을 수행(0보다 작으면 0, 255보다 크면 255로 표현)

# %% [markdown]
# # OpenCV 임계점 처리하기
# ## 이미지의 기본 이진화
# **메서드 threshold()**
# cv2.threshold(image, thresh, max_value, type) : 임계값을 기준으로 흑/백으로 분류하는 함수
# + image: 처리할 Gray Scale 이미지
# + thresh: 임계값(전체 픽셀에 적용) => 어떤 한계치를 초과할 경우 조치를 취하겠다!
# + max_value: 임계값을 넘었을때 적용할 값
# + type: 임계점을 처리하는 방식
#   + THRESH_BINARY : 임계값 보다 크면 max_value, 작으면 0
#   + THRESH_BINARY_INV : 임계값보다 작으면 max_value, 크면 0
#   + THRESH_TRUNC : 임계값보다 크면 임계값, 작으면 그대로
#   + THRESH_TOZERO : 임계값보다 크면 그대로, 작으면 0
#   + THRESH_TOZERO_INV : 임계값보다 크면 0. 작으면 그대로

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
import os
from model import get_classifier
from sklearn.metrics import f1_score, classification_report

os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)


def run_eval(model, loader):     
    preds = []
    labels = []
    for img, label in loader:
        y_prob = model.predict(img)
        y_pred = np.argmax(y_prob, axis=1)

        preds.append(y_pred)
        labels.append(label)
    
    y_pred = np.concatenate(preds, axis=0)
    y_test = np.concatenate(labels, axis=0)
    result = classification_report(y_test, y_pred, output_dict=True)

    return pd.DataFrame(result)


def freeze(model):
    for layer in model.layers:
        layer.trainable = False
        
    return model


def check_across_seeds(accs, f1s, result_df, num_classes=20):
    accs = np.array(accs)
    f1s = np.array(f1s)
    
    assert np.all(np.abs(accs[1:] - accs[:1]) < 1e-1) and np.all(np.abs(f1s[1:] - f1s[:1]) < 1e-1), "test results are not compatible \n{}\n{}".format(accs, f1s)

    print("*** CLASSWISE RESULT ***")
    cwise_result = result_df.loc[['f1-score', 'recall', 'support'], [str(i) for i in range(num_classes)]]
    cwise_result = cwise_result.rename(index={'f1-score' : 'f1', 'recall' : 'acc', 'support' : 'support'})
    print(cwise_result)
    
    print("\n*** AVG RESULT ***")
    avg_result = pd.Series({'f1' : result_df.loc['f1-score', 'macro avg'], 'acc' : result_df['accuracy'].values[0]})
    print(avg_result)
    
    
def main():
    ''' 
    Fill in the root directory path into DATA_DIR.
    You must write the subset directory for the specific split (train or valid).
    Under the root directory, the child folders should be "L2_3", "L2_10", ... , "L2_52"
    
    EX) if you named your valid dataset folder as "~/valid"
    then the child directory should be "~/valid/L2_3", "~/valid/L2_10", ... , "~/valid/L2_52"
    
    so you have to write as
    DATA_DIR = "~/valid"
    '''
    DATA_DIR = "YOUR DATA DIRECTORY"            
    IMAGENET_DEFAULT_MEAN = (0.485, 0.456, 0.406)
    IMAGENET_DEFAULT_VAR = (0.229 ** 2, 0.224 ** 2, 0.225 ** 2)
    
    
    ''' 
    You need to implement "get_classifier" function that returns your implemented model.
    "get_classifier" should return your model defined with your model configuration.
    Also, you should save your model.
    
    EX)
    model.save_weights('model.ckpt')
    or
    model.save('model.h5')
    '''
    CLF = get_classifier(num_classes=20) 
    CKPT_PATH = "YOUR CHECKPOINT PATH"  
    
    """ if saved with model.save_weights() """
    CLF.load_weights(CKPT_PATH).expect_partial()
    # if necessary
    # CLF.build(input_shape=[None, 224, 224, 3])
    # print(CLF.summary())
    
    """ if saved with model.save() """
    # CLF = load_model(CKPT_PATH)

    CLF = freeze(CLF)
    CLF.compile(metrics=['accuracy'])
    
    SEEDS = [0, 5, 10]
    ACC_LIST = []
    F1_LIST = []
    for seed in SEEDS:
        tf.random.set_seed(seed)
        
        loader = tf.keras.preprocessing.image_dataset_from_directory(
            directory=DATA_DIR,
            image_size=(256, 256),
            batch_size=128,
            shuffle=False
            )
        
        augmentation_layer = tf.keras.Sequential([
            tf.keras.layers.CenterCrop(224,224),
            tf.keras.layers.Rescaling(1./255),  
            tf.keras.layers.experimental.preprocessing.Normalization(mean=IMAGENET_DEFAULT_MEAN, variance=IMAGENET_DEFAULT_VAR)          
        ])
        loader = loader.map(lambda x,y: (augmentation_layer(x),y))
        
        RESULT_DF = run_eval(CLF, loader)
        ACC_LIST.append(RESULT_DF['accuracy'].values[0])
        F1_LIST.append(RESULT_DF.loc['f1-score', 'macro avg'])

    check_across_seeds(ACC_LIST, F1_LIST, RESULT_DF)

    
if __name__=="__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-8a5d772b3f8a> in <module>
#       4 import pandas as pd
#       5 import os
# ----> 6 from model import get_classifier
#       7 from sklearn.metrics import f1_score, classification_report
#       8
#
# ModuleNotFoundError: No module named 'model'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
